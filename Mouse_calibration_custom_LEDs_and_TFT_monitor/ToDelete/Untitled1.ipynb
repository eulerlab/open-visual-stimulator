# %%
import os
import glob
import math
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy.special as sse
import pylab
from scipy.optimize import curve_fit
from IPython import display

# Helpers
#
import scripts.spectrum as spc
import scripts.progress_bar as pbar
import scripts.spectrometer_helper as spm
import scripts.fitting_funcs as fit

# Set graphics to be plotted in the notebook
#
# %matplotlib inline 

# Seaborn plot settings
#
sns.set()

path_SpectCalibData = "spectrometer-calibration-files//"
spm_fileName     = path_SpectCalibData +"USB2+F02461_20171108_CC.Irradcal" 
spm_serialNumber = "USB2+F02461"

(spm_calib_values, 
 spm_calib_wavelengths) = spm.load_calibration_curves(spm.DevType.OO_USB2000, 
                                                      spm_fileName, spm_serialNumber)

# %%
plt.plot(spm_calib_wavelengths, spm_calib_values, color="black", label=spm_serialNumber)
plt.gca().set(xlabel="Wavelength [nm]", ylabel="[µJ/count]")     
plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left")

# %%
x_data = np.array(spm_calib_wavelengths)
np.savetxt("x_data.txt", x_data, delimiter=',')
y_data = np.array(spm_calib_values)
np.savetxt("y_data.txt", y_data, delimiter=',')
