# %%
import pandas as pd
import numpy as np
import os

# %%
os.listdir()
# Out:
# ['PM100D example.ipynb',
#  '.ipynb_checkpoints',
#  'led_spectra_after_teflon',
#  'stimulator_calibration_v0.1_fish_PM100D_powermeter.ipynb',
#  'load_n_arrange_spectra.ipynb',
#  'data']

# %%
after_teflon="led_spectra_after_teflon/"

test=pd.read_csv(after_teflon+"/"+"fish_red_led.csv",sep=",")

# %%
test.plot(y=0)

# %%
print(test)
